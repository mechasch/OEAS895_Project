# %% [markdown]
# # Determine and describe with appropriate figures and short paragraphs, the different data types you intend to use for your project and explore them in some detail.
#
# # Include a clear description of each data type with information on how to access is. If it is your own data, state that.
#
# # Discuss the spatial and temporal distrobution of the data types.
#
# # Discuss the level of overlap in coverage and resolution of the different data types.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
infile = 'Combined_List_R_UPDATED_HEADERS.csv'
data = pd.read_csv(infile, sep = (','))

#Let's take a look at the data.
data
# Out:
#           Date  Month  Day  Year Depth_ID  Depth   Time   NH4     Urea    DIN  \
# 0     6/6/2016      6    6  2016       D1   0.50  14:00  0.46  0.08000  0.557
# 1     6/6/2016      6    6  2016       D2   5.00  14:00  2.05  0.08000  0.346
# 2     6/7/2016      6    7  2016       D1   0.50  14:00  0.36  0.08000  0.275
# 3     6/7/2016      6    7  2016       D2   5.50  14:00  2.45  0.10441  1.506
# 4     6/8/2016      6    8  2016       D1   0.50  14:00  0.08  0.08000  0.214
# ..         ...    ...  ...   ...      ...    ...    ...   ...      ...    ...
# 925  10/1/2019     10    1  2019       D2   3.00  14:00   NaN  0.08000  4.870
# 926  10/1/2019     10    1  2019       D3   5.75  14:00   NaN  0.08000  4.870
# 927  10/1/2019     10    1  2019       D1   0.25  14:00   NaN  0.11000  1.660
# 928  10/1/2019     10    1  2019       D2   0.75  14:00   NaN  0.16000  1.700
# 929  10/1/2019     10    1  2019       D3   2.00  14:00   NaN  0.20000  1.920
#
# ...

# %%
#Check to see where the variable data points lie. Some may be below zero or very high
fig, axs = plt.subplots(4, 2, figsize = (8, 8), dpi = 100)

axs[0, 0].scatter(data.Depth_ID,data.DIN)
axs[0, 0].set_xlabel('Depth ID')
axs[0, 0].set_ylabel('DIN')

axs[0, 1].scatter(data.Depth_ID,data.Sal)
axs[0, 1].set_xlabel('Depth ID')
axs[0, 1].set_ylabel('Salinity')

axs[1, 0].scatter(data.Depth_ID,data.pH)
axs[1, 0].set_xlabel('Depth ID')
axs[1, 0].set_ylabel('pH')

axs[1, 1].scatter(data.Depth_ID,data.Chl)
axs[1, 1].set_xlabel('Depth ID')
axs[1, 1].set_ylabel('Chl')

axs[2, 0].scatter(data.Depth_ID,data.Turb)
axs[2, 0].set_xlabel('Depth ID')
axs[2, 0].set_ylabel('Turbidity')

axs[2, 1].scatter(data.Depth_ID,data.DO)
axs[2, 1].set_xlabel('Depth ID')
axs[2, 1].set_ylabel('Dissolved Oxygen')

axs[3, 0].scatter(data.Depth_ID,data.Temp)
axs[3, 0].set_xlabel('Depth ID')
axs[3, 0].set_ylabel('Temperature')
# Out:
# Text(0, 0.5, 'Temperature')

# %%
data.describe()
# Out:
#             Month         Day         Year       Depth        Urea  \
# count  930.000000  930.000000   930.000000  930.000000  908.000000
# mean     7.416129   15.277419  2017.639785    2.269355    0.136437
# std      1.076192    8.516964     1.184002    1.859547    0.196375
# min      5.000000    1.000000  2016.000000    0.000000    0.031950
# 25%      7.000000    8.000000  2016.000000    0.500000    0.080000
# 50%      7.000000   15.000000  2018.000000    1.750000    0.080000
# 75%      8.000000   22.000000  2019.000000    3.750000    0.100000
# max     10.000000   31.000000  2019.000000    6.000000    2.414990
#
#               DIN         PO4        Temp         Sal          pH         Chl  \
# count  929.000000  929.000000  930.000000  930.000000  771.000000  930.000000
# mean     3.094700    2.279135   27.684155   20.006839    7.685525   28.342113
# std     13.936814    1.584062    2.015112    3.398665    0.312475   38.588654
# ...

# %% [markdown]
# # From this describe function of our data, we can clearly see that some values, such as DIN, salinity, and turbidity have erroneous values, skewing the dataset. From personal use of the instruments, I also know that YSI 6600 V2 sondes are not accurate above roughly 200 ug/L of chlorophyll a. To correct for these datapoints, we will have to edit the thresholds of each variable, remove the datapoints that fall in line with erroneous values.

# %%
# Making corrections to data that appear to have outliers (negative values, extreme high values, etc.)
corr_data = data[data.DIN < 50]
corr_data = corr_data[corr_data.DIN > 0.14] #This is the detection limit of NOx
corr_data = corr_data[corr_data.Chl < 200]
corr_data = corr_data[corr_data.Turb > 0] 
corr_data = corr_data[corr_data.Sal > 15] #Corrected for known low salinity values due to probe failure. Will also correct for error temperature values

corr_data.Precipitation = corr_data.Precipitation * 8 * 0.0254 #Transforming precipitation from 1/8" to inches to meters
corr_data.Wind_Speed = corr_data.Wind_Speed * 0.44704 #Transforming wind speed from miles/hour to meters/second

# %%
corr_data.describe()
# Out:
#             Month         Day         Year       Depth        Urea  \
# count  684.000000  684.000000   684.000000  684.000000  675.000000
# mean     7.500000   15.464912  2017.561404    2.547149    0.145013
# std      1.073438    8.638177     1.230661    1.915507    0.217721
# min      5.000000    1.000000  2016.000000    0.250000    0.031950
# 25%      7.000000    8.000000  2016.000000    0.500000    0.080000
# 50%      8.000000   15.000000  2018.000000    2.375000    0.080000
# 75%      8.000000   22.250000  2019.000000    4.750000    0.110000
# max     10.000000   31.000000  2019.000000    6.000000    2.414990
#
#               DIN         PO4        Temp         Sal          pH         Chl  \
# count  684.000000  684.000000  684.000000  684.000000  558.000000  684.000000
# mean     2.703196    2.119680   27.628567   20.863830    7.668763   23.253817
# std      5.130208    1.485246    2.017327    2.556322    0.288873   17.596858
# ...

# %% [markdown]
# # These values look a lot better, with no noticable extremely high or low/negative values.

# %%
plt.scatter(corr_data[corr_data.Year==2016].DIN,-corr_data[corr_data.Year==2016].Depth)
plt.xlabel('DIN (uM)')
plt.ylabel('Depth (m)')
# Out:
# Text(0, 0.5, 'Depth (m)')

# %%
#2016 sampling completed ONLY at NYCC
plt.scatter(corr_data[corr_data.Year==2016].Depth_ID, corr_data[corr_data.Year==2016].DIN)
plt.xlabel('Depth_ID')
plt.ylabel('DIN (uM)')
# Out:
# Text(0, 0.5, 'DIN (uM)')

# %%
#2018 sampling completed MOSTLY at AC
plt.scatter(corr_data[corr_data.Year==2018].Depth_ID, corr_data[corr_data.Year==2018].DIN)
plt.xlabel('Depth_ID')
plt.ylabel('DIN (uM)')
# Out:
# Text(0, 0.5, 'DIN (uM)')

# %% [markdown]
# # Perhaps I should work by station rather than having their data combined

# %%
#Looking at all of the data
fig, axs = plt.subplots(5, 2, figsize = (8, 8), dpi = 300)

axs[0, 0].scatter(corr_data.DIN,corr_data.Sal)
axs[0, 0].set_xlabel('DIN (uM)')
axs[0, 0].set_ylabel('Salinity')

axs[0, 1].scatter(corr_data.DIN,corr_data.pH)
axs[0, 1].set_xlabel('DIN (uM)')
axs[0, 1].set_ylabel('pH')

axs[1, 0].scatter(corr_data.DIN,corr_data.Chl)
axs[1, 0].set_xlabel('DIN (uM)')
axs[1, 0].set_ylabel('Chlorophyll (ug/L)')

axs[1, 1].scatter(corr_data.DIN,corr_data.Turb)
axs[1, 1].set_xlabel('DIN (uM)')
axs[1, 1].set_ylabel('Turbidity')

axs[2, 0].scatter(corr_data.DIN,corr_data.DO)
axs[2, 0].set_xlabel('DIN (uM)')
axs[2, 0].set_ylabel('Dissolved Oxygen (mg/L)')

axs[2, 1].scatter(corr_data.DIN,corr_data.Tide)
axs[2, 1].set_xlabel('DIN (uM)')
axs[2, 1].set_ylabel('Tide (MSL (m))')

axs[3, 0].scatter(corr_data.DIN,corr_data.Precipitation)
axs[3, 0].set_xlabel('DIN (uM)')
axs[3, 0].set_ylabel('Precipitation (m)')

axs[3, 1].scatter(corr_data.DIN,corr_data.Wind_Speed)
axs[3, 1].set_xlabel('DIN (uM)')
axs[3, 1].set_ylabel('Wind Speed (m/s)')

axs[4, 0].scatter(corr_data.DIN,corr_data.Wind_Dir)
axs[4, 0].set_xlabel('DIN (uM)')
axs[4, 0].set_ylabel('Wind Direction (degrees)')

axs[4, 1].scatter(corr_data.DIN,corr_data.Temp)
axs[4, 1].set_xlabel('DIN (uM)')
axs[4, 1].set_ylabel('Temperature (\N{DEGREE SIGN}C)')
# Out:
# Text(0, 0.5, 'Temperature (°C)')

# %%
#Looking at temperature
corr_data_2016 = corr_data[corr_data.Year == 2016]
corr_data_2017 = corr_data[corr_data.Year == 2017]
corr_data_2018 = corr_data[corr_data.Year == 2018]
corr_data_2019 = corr_data[corr_data.Year == 2019]

fig, axs = plt.subplots(2, 2, figsize = (8, 8), dpi = 100)

axs[0, 0].scatter(corr_data_2016.Temp, corr_data_2016.DIN)
axs[0, 0].set_title('2016')
axs[0, 0].set_ylabel('DIN (uM)')
axs[0, 0].set_xlabel('Temperature (\N{DEGREE SIGN}C)')

axs[0, 1].scatter(corr_data_2017.Temp, corr_data_2017.DIN)
axs[0, 1].set_title('2017')
axs[0, 1].set_ylabel('DIN (uM)')
axs[0, 1].set_xlabel('Temperature (\N{DEGREE SIGN}C)')

axs[1, 0].scatter(corr_data_2018.Temp, corr_data_2018.DIN)
axs[1, 0].set_title('2018')
axs[1, 0].set_ylabel('DIN (uM)')
axs[1, 0].set_xlabel('Temperature (\N{DEGREE SIGN}C)')

axs[1, 1].scatter(corr_data_2019.Temp, corr_data_2019.DIN)
axs[1, 1].set_title('2019')
axs[1, 1].set_ylabel('DIN (uM)')
axs[1, 1].set_xlabel('Temperature (\N{DEGREE SIGN}C)')
# Out:
# Text(0.5, 0, 'Temperature (°C)')

# %%
#Looking at salinity
corr_data_2016 = corr_data[corr_data.Year == 2016]
corr_data_2017 = corr_data[corr_data.Year == 2017]
corr_data_2018 = corr_data[corr_data.Year == 2018]
corr_data_2019 = corr_data[corr_data.Year == 2019]

fig, axs = plt.subplots(2, 2, figsize = (8, 8), dpi = 100)

axs[0, 0].scatter(corr_data_2016.Sal, corr_data_2016.DIN)
axs[0, 0].set_title('2016')
axs[0, 0].set_ylabel('DIN (uM)')
axs[0, 0].set_xlabel('Salinity')

axs[0, 1].scatter(corr_data_2017.Sal, corr_data_2017.DIN)
axs[0, 1].set_title('2017')
axs[0, 1].set_ylabel('DIN (uM)')
axs[0, 1].set_xlabel('Salinity')

axs[1, 0].scatter(corr_data_2018.Sal, corr_data_2018.DIN)
axs[1, 0].set_title('2018')
axs[1, 0].set_ylabel('DIN (uM)')
axs[1, 0].set_xlabel('Salinity')

axs[1, 1].scatter(corr_data_2019.Sal, corr_data_2019.DIN)
axs[1, 1].set_title('2019')
axs[1, 1].set_ylabel('DIN (uM)')
axs[1, 1].set_xlabel('Salinity')
# Out:
# Text(0.5, 0, 'Salinity')

# %%
#Looking at pH
corr_data_2016 = corr_data[corr_data.Year == 2016]
corr_data_2017 = corr_data[corr_data.Year == 2017]
corr_data_2018 = corr_data[corr_data.Year == 2018]
corr_data_2019 = corr_data[corr_data.Year == 2019]

fig, axs = plt.subplots(2, 2, figsize = (8, 8), dpi = 100)

axs[0, 0].scatter(corr_data_2016.pH, corr_data_2016.DIN)
axs[0, 0].set_title('2016')
axs[0, 0].set_ylabel('DIN (uM)')
axs[0, 0].set_xlabel('pH')

axs[0, 1].scatter(corr_data_2017.pH, corr_data_2017.DIN)
axs[0, 1].set_title('2017')
axs[0, 1].set_ylabel('DIN (uM)')
axs[0, 1].set_xlabel('pH')

axs[1, 0].scatter(corr_data_2018.pH, corr_data_2018.DIN)
axs[1, 0].set_title('2018')
axs[1, 0].set_ylabel('DIN (uM)')
axs[1, 0].set_xlabel('pH')

axs[1, 1].scatter(corr_data_2019.pH, corr_data_2019.DIN)
axs[1, 1].set_title('2019')
axs[1, 1].set_ylabel('DIN (uM)')
axs[1, 1].set_xlabel('pH')
# Out:
# Text(0.5, 0, 'pH')

# %%
#Looking at Chlorophyll
corr_data_2016 = corr_data[corr_data.Year == 2016]
corr_data_2017 = corr_data[corr_data.Year == 2017]
corr_data_2018 = corr_data[corr_data.Year == 2018]
corr_data_2019 = corr_data[corr_data.Year == 2019]

fig, axs = plt.subplots(2, 2, figsize = (8, 8), dpi = 100)

axs[0, 0].scatter(corr_data_2016.Chl, corr_data_2016.DIN)
axs[0, 0].set_title('2016')
axs[0, 0].set_ylabel('DIN (uM)')
axs[0, 0].set_xlabel('Chlorophyll (ug/L)')

axs[0, 1].scatter(corr_data_2017.Chl, corr_data_2017.DIN)
axs[0, 1].set_title('2017')
axs[0, 1].set_ylabel('DIN (uM)')
axs[0, 1].set_xlabel('Chlorophyll (ug/L)')

axs[1, 0].scatter(corr_data_2018.Chl, corr_data_2018.DIN)
axs[1, 0].set_title('2018')
axs[1, 0].set_ylabel('DIN (uM)')
axs[1, 0].set_xlabel('Chlorophyll (ug/L)')

axs[1, 1].scatter(corr_data_2019.Chl, corr_data_2019.DIN)
axs[1, 1].set_title('2019')
axs[1, 1].set_ylabel('DIN (uM)')
axs[1, 1].set_xlabel('Chlorophyll (ug/L)')
# Out:
# Text(0.5, 0, 'Chlorophyll (ug/L)')

# %%
#Looking at Turbidity
corr_data_2016 = corr_data[corr_data.Year == 2016]
corr_data_2017 = corr_data[corr_data.Year == 2017]
corr_data_2018 = corr_data[corr_data.Year == 2018]
corr_data_2019 = corr_data[corr_data.Year == 2019]

fig, axs = plt.subplots(2, 2, figsize = (8, 8), dpi = 100)

axs[0, 0].scatter(corr_data_2016.Turb, corr_data_2016.DIN)
axs[0, 0].set_title('2016')
axs[0, 0].set_ylabel('DIN (uM)')
axs[0, 0].set_xlabel('Turbidity')

axs[0, 1].scatter(corr_data_2017.Turb, corr_data_2017.DIN)
axs[0, 1].set_title('2017')
axs[0, 1].set_ylabel('DIN (uM)')
axs[0, 1].set_xlabel('Turbidity')

axs[1, 0].scatter(corr_data_2018.Turb, corr_data_2018.DIN)
axs[1, 0].set_title('2018')
axs[1, 0].set_ylabel('DIN (uM)')
axs[1, 0].set_xlabel('Turbidity')

axs[1, 1].scatter(corr_data_2019.Turb, corr_data_2019.DIN)
axs[1, 1].set_title('2019')
axs[1, 1].set_ylabel('DIN (uM)')
axs[1, 1].set_xlabel('Turbidity')
# Out:
# Text(0.5, 0, 'Turbidity')

# %%
#Looking at Dissolved Oxygen
corr_data_2016 = corr_data[corr_data.Year == 2016]
corr_data_2017 = corr_data[corr_data.Year == 2017]
corr_data_2018 = corr_data[corr_data.Year == 2018]
corr_data_2019 = corr_data[corr_data.Year == 2019]

fig, axs = plt.subplots(2, 2, figsize = (8, 8), dpi = 100)

axs[0, 0].scatter(corr_data_2016.DO, corr_data_2016.DIN)
axs[0, 0].set_title('2016')
axs[0, 0].set_ylabel('DIN (uM)')
axs[0, 0].set_xlabel('Dissolved Oxygen (mg/L)')

axs[0, 1].scatter(corr_data_2017.DO, corr_data_2017.DIN)
axs[0, 1].set_title('2017')
axs[0, 1].set_ylabel('DIN (uM)')
axs[0, 1].set_xlabel('Dissolved Oxygen (mg/L)')

axs[1, 0].scatter(corr_data_2018.DO, corr_data_2018.DIN)
axs[1, 0].set_title('2018')
axs[1, 0].set_ylabel('DIN (uM)')
axs[1, 0].set_xlabel('Dissolved Oxygen (mg/L)')

axs[1, 1].scatter(corr_data_2019.DO, corr_data_2019.DIN)
axs[1, 1].set_title('2019')
axs[1, 1].set_ylabel('DIN (uM)')
axs[1, 1].set_xlabel('Dissolved Oxygen (mg/L)')
# Out:
# Text(0.5, 0, 'Dissolved Oxygen (mg/L)')

# %%
#Looking at Tide
corr_data_2016 = corr_data[corr_data.Year == 2016]
corr_data_2017 = corr_data[corr_data.Year == 2017]
corr_data_2018 = corr_data[corr_data.Year == 2018]
corr_data_2019 = corr_data[corr_data.Year == 2019]

fig, axs = plt.subplots(2, 2, figsize = (8, 8), dpi = 100)

axs[0, 0].scatter(corr_data_2016.Tide, corr_data_2016.DIN)
axs[0, 0].set_title('2016')
axs[0, 0].set_ylabel('DIN (uM)')
axs[0, 0].set_xlabel('Tide (MSL (m))')

axs[0, 1].scatter(corr_data_2017.Tide, corr_data_2017.DIN)
axs[0, 1].set_title('2017')
axs[0, 1].set_ylabel('DIN (uM)')
axs[0, 1].set_xlabel('Tide (MSL (m))')

axs[1, 0].scatter(corr_data_2018.Tide, corr_data_2018.DIN)
axs[1, 0].set_title('2018')
axs[1, 0].set_ylabel('DIN (uM)')
axs[1, 0].set_xlabel('Tide (MSL (m))')

axs[1, 1].scatter(corr_data_2019.Tide, corr_data_2019.DIN)
axs[1, 1].set_title('2019')
axs[1, 1].set_ylabel('DIN (uM)')
axs[1, 1].set_xlabel('Tide (MSL (m))')
# Out:
# Text(0.5, 0, 'Tide (MSL (m))')

# %%
#Looking at Precipitation

corr_data_2016 = corr_data[corr_data.Year == 2016]
corr_data_2017 = corr_data[corr_data.Year == 2017]
corr_data_2018 = corr_data[corr_data.Year == 2018]
corr_data_2019 = corr_data[corr_data.Year == 2019]

fig, axs = plt.subplots(2, 2, figsize = (8, 8), dpi = 100)

axs[0, 0].scatter(corr_data_2016.Precipitation, corr_data_2016.DIN)
axs[0, 0].set_title('2016')
axs[0, 0].set_ylabel('DIN (uM)')
axs[0, 0].set_xlabel('Precipitation (m)')

axs[0, 1].scatter(corr_data_2017.Precipitation, corr_data_2017.DIN)
axs[0, 1].set_title('2017')
axs[0, 1].set_ylabel('DIN (uM)')
axs[0, 1].set_xlabel('Precipitation (m)')

axs[1, 0].scatter(corr_data_2018.Precipitation, corr_data_2018.DIN)
axs[1, 0].set_title('2018')
axs[1, 0].set_ylabel('DIN (uM)')
axs[1, 0].set_xlabel('Precipitation (m)')

axs[1, 1].scatter(corr_data_2019.Precipitation, corr_data_2019.DIN)
axs[1, 1].set_title('2019')
axs[1, 1].set_ylabel('DIN (uM)')
axs[1, 1].set_xlabel('Precipitation (m)')
# Out:
# Text(0.5, 0, 'Precipitation (m)')

# %%
#Looking at wind speed
corr_data_2016 = corr_data[corr_data.Year == 2016]
corr_data_2017 = corr_data[corr_data.Year == 2017]
corr_data_2018 = corr_data[corr_data.Year == 2018]
corr_data_2019 = corr_data[corr_data.Year == 2019]

fig, axs = plt.subplots(2, 2, figsize = (8, 8), dpi = 100)

axs[0, 0].scatter(corr_data_2016.Wind_Speed, corr_data_2016.DIN)
axs[0, 0].set_title('2016')
axs[0, 0].set_ylabel('DIN (uM)')
axs[0, 0].set_xlabel('Wind Speed (m/s)')

axs[0, 1].scatter(corr_data_2017.Wind_Speed, corr_data_2017.DIN)
axs[0, 1].set_title('2017')
axs[0, 1].set_ylabel('DIN (uM)')
axs[0, 1].set_xlabel('Wind Speed (m/s)')

axs[1, 0].scatter(corr_data_2018.Wind_Speed, corr_data_2018.DIN)
axs[1, 0].set_title('2018')
axs[1, 0].set_ylabel('DIN (uM)')
axs[1, 0].set_xlabel('Wind Speed (m/s)')

axs[1, 1].scatter(corr_data_2019.Wind_Speed, corr_data_2019.DIN)
axs[1, 1].set_title('2019')
axs[1, 1].set_ylabel('DIN (uM)')
axs[1, 1].set_xlabel('Wind Speed (m/s)')
# Out:
# Text(0.5, 0, 'Wind Speed (m/s)')

# %%
#Make a windrose plot to look at wind direction and DIN concentration

from windrose import WindroseAxes
from matplotlib import pyplot as plt
import matplotlib.cm as cm
from numpy.random import random
from numpy import arange

ax = WindroseAxes.from_ax()
ax.bar(corr_data.Wind_Dir, corr_data.DIN, bins = np.arange(0,50,10), opening = 0.8, edgecolor = 'white')
ax.set_legend(loc = 'upper left', title = 'DIN (uM)')
ax.set_title('Wind Direction and DIN concentration')
# Out:
# Text(0.5, 1.05, 'Wind Direction and DIN concentration')

# %%
#Temperature
corr_data_D1 = corr_data[corr_data.Depth_ID == 'D1']
corr_data_D2 = corr_data[corr_data.Depth_ID == 'D2']
corr_data_D3 = corr_data[corr_data.Depth_ID == 'D3']

fig, axs = plt.subplots(3, 1, figsize = (8, 8), dpi = 100)

axs[0].scatter(corr_data_D1.Temp, corr_data_D1.DIN)
axs[0].set_title('D1')
axs[0].set_ylabel('DIN (uM)')
axs[0].set_xlabel('Temperature (\N{DEGREE SIGN}C)')

axs[1].scatter(corr_data_D2.Temp, corr_data_D2.DIN)
axs[1].set_title('D2')
axs[1].set_ylabel('DIN (uM)')
axs[1].set_xlabel('Temperature (\N{DEGREE SIGN}C)')

axs[2].scatter(corr_data_D3.Temp, corr_data_D3.DIN)
axs[2].set_title('D3')
axs[2].set_ylabel('DIN (uM)')
axs[2].set_xlabel('Temperature (\N{DEGREE SIGN}C)')
# Out:
# Text(0.5, 0, 'Temperature (°C)')

# %%
#Salinity
corr_data_D1 = corr_data[corr_data.Depth_ID == 'D1']
corr_data_D2 = corr_data[corr_data.Depth_ID == 'D2']
corr_data_D3 = corr_data[corr_data.Depth_ID == 'D3']

fig, axs = plt.subplots(3, 1, figsize = (8, 8), dpi = 100)

axs[0].scatter(corr_data_D1.Sal, corr_data_D1.DIN)
axs[0].set_title('D1')
axs[0].set_ylabel('DIN (uM)')
axs[0].set_xlabel('Salinity')

axs[1].scatter(corr_data_D2.Sal, corr_data_D2.DIN)
axs[1].set_title('D2')
axs[1].set_ylabel('DIN (uM)')
axs[1].set_xlabel('Salinity')

axs[2].scatter(corr_data_D3.Sal, corr_data_D3.DIN)
axs[2].set_title('D3')
axs[2].set_ylabel('DIN (uM)')
axs[2].set_xlabel('Salinity')
# Out:
# Text(0.5, 0, 'Salinity')

# %%
#pH
corr_data_D1 = corr_data[corr_data.Depth_ID == 'D1']
corr_data_D2 = corr_data[corr_data.Depth_ID == 'D2']
corr_data_D3 = corr_data[corr_data.Depth_ID == 'D3']

fig, axs = plt.subplots(3, 1, figsize = (8, 8), dpi = 100)

axs[0].scatter(corr_data_D1.pH, corr_data_D1.DIN)
axs[0].set_title('D1')
axs[0].set_ylabel('DIN (uM)')
axs[0].set_xlabel('pH')

axs[1].scatter(corr_data_D2.pH, corr_data_D2.DIN)
axs[1].set_title('D2')
axs[1].set_ylabel('DIN (uM)')
axs[1].set_xlabel('pH')

axs[2].scatter(corr_data_D3.pH, corr_data_D3.DIN)
axs[2].set_title('D3')
axs[2].set_ylabel('DIN (uM)')
axs[2].set_xlabel('pH)')
# Out:
# Text(0.5, 0, 'pH)')

# %%
#Chlorophyll
corr_data_D1 = corr_data[corr_data.Depth_ID == 'D1']
corr_data_D2 = corr_data[corr_data.Depth_ID == 'D2']
corr_data_D3 = corr_data[corr_data.Depth_ID == 'D3']

fig, axs = plt.subplots(3, 1, figsize = (8, 8), dpi = 100)

axs[0].scatter(corr_data_D1.Chl, corr_data_D1.DIN)
axs[0].set_title('D1')
axs[0].set_ylabel('DIN (uM)')
axs[0].set_xlabel('Chlorophyll (ug/L)')

axs[1].scatter(corr_data_D2.Chl, corr_data_D2.DIN)
axs[1].set_title('D2')
axs[1].set_ylabel('DIN (uM)')
axs[1].set_xlabel('Chlorophyll (ug/L)')

axs[2].scatter(corr_data_D3.Chl, corr_data_D3.DIN)
axs[2].set_title('D3')
axs[2].set_ylabel('DIN (uM)')
axs[2].set_xlabel('Chlorophyll (ug/L)')
# Out:
# Text(0.5, 0, 'Chlorophyll (ug/L)')

# %%
#Turbidity
corr_data_D1 = corr_data[corr_data.Depth_ID == 'D1']
corr_data_D2 = corr_data[corr_data.Depth_ID == 'D2']
corr_data_D3 = corr_data[corr_data.Depth_ID == 'D3']

fig, axs = plt.subplots(3, 1, figsize = (8, 8), dpi = 100)

axs[0].scatter(corr_data_D1.Turb, corr_data_D1.DIN)
axs[0].set_title('D1')
axs[0].set_ylabel('DIN (uM)')
axs[0].set_xlabel('Turbidity')

axs[1].scatter(corr_data_D2.Turb, corr_data_D2.DIN)
axs[1].set_title('D2')
axs[1].set_ylabel('DIN (uM)')
axs[1].set_xlabel('Turbidity')

axs[2].scatter(corr_data_D3.Turb, corr_data_D3.DIN)
axs[2].set_title('D3')
axs[2].set_ylabel('DIN (uM)')
axs[2].set_xlabel('Turbidity')
# Out:
# Text(0.5, 0, 'Turbidity')

# %%
#Dissolved Oxygen
corr_data_D1 = corr_data[corr_data.Depth_ID == 'D1']
corr_data_D2 = corr_data[corr_data.Depth_ID == 'D2']
corr_data_D3 = corr_data[corr_data.Depth_ID == 'D3']

fig, axs = plt.subplots(3, 1, figsize = (8, 8), dpi = 100)

axs[0].scatter(corr_data_D1.DO, corr_data_D1.DIN)
axs[0].set_title('D1')
axs[0].set_ylabel('DIN (uM)')
axs[0].set_xlabel('Dissolved Oxygen (mg/L)')

axs[1].scatter(corr_data_D2.DO, corr_data_D2.DIN)
axs[1].set_title('D2')
axs[1].set_ylabel('DIN (uM)')
axs[1].set_xlabel('Dissolved Oxygen (mg/L)')

axs[2].scatter(corr_data_D3.DO, corr_data_D3.DIN)
axs[2].set_title('D3')
axs[2].set_ylabel('DIN (uM)')
axs[2].set_xlabel('Dissolved Oxygen (mg/L)')
# Out:
# Text(0.5, 0, 'Dissolved Oxygen (mg/L)')

# %%
#Tide
corr_data_D1 = corr_data[corr_data.Depth_ID == 'D1']
corr_data_D2 = corr_data[corr_data.Depth_ID == 'D2']
corr_data_D3 = corr_data[corr_data.Depth_ID == 'D3']

fig, axs = plt.subplots(3, 1, figsize = (8, 8), dpi = 100)

axs[0].scatter(corr_data_D1.Tide, corr_data_D1.DIN)
axs[0].set_title('D1')
axs[0].set_ylabel('DIN (uM)')
axs[0].set_xlabel('Tide (MSL (m))')

axs[1].scatter(corr_data_D2.Tide, corr_data_D2.DIN)
axs[1].set_title('D2')
axs[1].set_ylabel('DIN (uM)')
axs[1].set_xlabel('Tide (MSL (m))')

axs[2].scatter(corr_data_D3.Tide, corr_data_D3.DIN)
axs[2].set_title('D3')
axs[2].set_ylabel('DIN (uM)')
axs[2].set_xlabel('Tide (MSL (m))')
# Out:
# Text(0.5, 0, 'Tide (MSL (m))')

# %%
#Precipitation
corr_data_D1 = corr_data[corr_data.Depth_ID == 'D1']
corr_data_D2 = corr_data[corr_data.Depth_ID == 'D2']
corr_data_D3 = corr_data[corr_data.Depth_ID == 'D3']

fig, axs = plt.subplots(3, 1, figsize = (8, 8), dpi = 100)

axs[0].scatter(corr_data_D1.Precipitation, corr_data_D1.DIN)
axs[0].set_title('D1')
axs[0].set_ylabel('DIN (uM)')
axs[0].set_xlabel('Precipitation (m)')

axs[1].scatter(corr_data_D2.Precipitation, corr_data_D2.DIN)
axs[1].set_title('D2')
axs[1].set_ylabel('DIN (uM)')
axs[1].set_xlabel('Precipitation (m)')

axs[2].scatter(corr_data_D3.Precipitation, corr_data_D3.DIN)
axs[2].set_title('D3')
axs[2].set_ylabel('DIN (uM)')
axs[2].set_xlabel('Precipitation (m)')
# Out:
# Text(0.5, 0, 'Precipitation (m)')

# %%
#Wind Speed
corr_data_D1 = corr_data[corr_data.Depth_ID == 'D1']
corr_data_D2 = corr_data[corr_data.Depth_ID == 'D2']
corr_data_D3 = corr_data[corr_data.Depth_ID == 'D3']

fig, axs = plt.subplots(3, 1, figsize = (8, 8), dpi = 100)

axs[0].scatter(corr_data_D1.Wind_Speed, corr_data_D1.DIN)
axs[0].set_title('D1')
axs[0].set_ylabel('DIN (uM)')
axs[0].set_xlabel('Wind speed (m/s)')

axs[1].scatter(corr_data_D2.Wind_Speed, corr_data_D2.DIN)
axs[1].set_title('D2')
axs[1].set_ylabel('DIN (uM)')
axs[1].set_xlabel('Wind speed (m/s)')

axs[2].scatter(corr_data_D3.Wind_Speed, corr_data_D3.DIN)
axs[2].set_title('D3')
axs[2].set_ylabel('DIN (uM)')
axs[2].set_xlabel('Wind speed (m/s)')
# Out:
# Text(0.5, 0, 'Wind speed (m/s)')

# %%
month = np.arange(0,12,1.0)
plt.hist(corr_data[corr_data.Year == 2016].Month, facecolor = "none", edgecolor = "deepskyblue", lw = 5, align='mid', bins = month, hatch = 'x')
plt.hist(corr_data[corr_data.Year == 2017].Month, facecolor = "none", edgecolor = "lime", lw = 5, align='mid', bins = month, hatch = '|')
plt.hist(corr_data[corr_data.Year == 2018].Month, facecolor = "none", edgecolor = "red", lw = 5, align='mid', bins = month, hatch = '-')
plt.hist(corr_data[corr_data.Year == 2019].Month, facecolor = "none", edgecolor = "darkorange", lw = 5, align='mid', bins = month, hatch = '/')
plt.xlim([1,12])
plt.xlabel("Month")
plt.ylabel("Sample count")
labels = ("2016","2017","2018","2019")
plt.legend(labels)

# %% [markdown]
# # From this histogram, we can see that the data coverage is generally summer months, namely June, July, and August. 2019 Is the only year that expands beyond that temporal window to include both May and October, though many fewer samples were taken during those months. Overall, there is good temporal overlap with all of the data from each year.

# %%
plt.scatter(corr_data_D1.Chl, corr_data_D1.DO)

# %%
plt.scatter(corr_data_D1.Temp, corr_data_D1.Sal)

# %%
plt.scatter(corr_data.DIN, corr_data.Temp)

# %%
#plt.scatter(corr_data.Month, corr_data.Chl)
#plt.scatter(corr_data.Month, corr_data.Temp)

fig, axs = plt.subplots(2, 2, figsize = (8, 8), dpi = 100)

axs[0, 0].scatter(corr_data.Month, corr_data.Chl)
axs[0, 0].set_xlabel('Month')
axs[0, 0].set_ylabel('Chlorophyll')

axs[0, 1].scatter(corr_data.Month, corr_data.Temp)
axs[0, 1].set_xlabel('Month')
axs[0, 1].set_ylabel('Temperature')

axs[1, 0].scatter(corr_data.Year, corr_data.Chl)
axs[1, 0].set_xlabel('Year')
axs[1, 0].set_ylabel('Chlorophyll')

axs[1, 1].scatter(corr_data.Year, corr_data.Temp)
axs[1, 1].set_xlabel('Year')
axs[1, 1].set_ylabel('Temperature')
# Out:
# Text(0, 0.5, 'Temperature')

# %%
plt.scatter(corr_data.DIN, -corr_data.Depth)

# %%
plt.scatter(corr_data.Temp, -corr_data.Depth)

# %%
import random

rand = random.shuffle(data)

rand
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# F:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 626
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-b3e00c27bfb2> in <module>
#       1 import random
#       2
# ...
